# %% [markdown]
# # Model Specifications:

# %% [markdown]
# - Oversampling : DONE - minority
# - Age Groups: DONE
# - Outliers: NO
#
#
#
#                    precision  recall  f1-score   support
#
#            0       0.50      0.55      0.52        29
#            1       0.80      0.76      0.78        67
#
#       accuracy                         0.70        96
#       macro avg    0.65      0.66      0.65        96
#       weighted avg 0.71      0.70      0.70        96

# %% [markdown]
# - Oversampling : DONE - minority
# - Age Groups: DONE
# - Outliers: DONE
#
#                   precision    recall  f1-score   support
#
#            0       0.56      0.62      0.59        29
#            1       0.83      0.79      0.81        67
#
#       accuracy                         0.74        96
#       macro avg    0.70      0.71      0.70        96
#       weighted avg 0.75      0.74      0.74        96

# %% [markdown]
# - Oversampling : No
# - Age Groups: No
# - Outliers: No
#
#                   precision    recall  f1-score   support
#
#            0       0.65      0.45      0.53        29
#            1       0.79      0.90      0.84        67
#
#       accuracy                         0.76        96
#       macro avg    0.72      0.67      0.68        96
#       weighted avg 0.75      0.76      0.75        96

# %% [markdown]
# - Oversampling : DONE
# - Age Groups: DONE
# - Outliers: No
#
#
#
#
#
#               precision    recall  f1-score   support
#
#            0       0.52      0.59      0.55        29
#            1       0.81      0.76      0.78        67
#
#       accuracy                         0.71        96
#       macro avg    0.66      0.67      0.67        96
#       weighted avg 0.72      0.71      0.71        96

# %% [markdown]
# - Oversampling : DONE - minority
# - Age Groups: No
# - Outliers: No
#
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.76      0.65        29
#            1       0.88      0.75      0.81        67
#
#       accuracy                         0.75        96
#       macro avg    0.72      0.75      0.73        96
#       weighted avg 0.78      0.75      0.76        96

# %% [markdown]
# - Oversampling : No
# - Age Groups: DONE
# - Outliers: No
#
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.48      0.51        29
#            1       0.79      0.82      0.80        67
#
#       accuracy                         0.72        96
#       macro avg    0.66      0.65      0.66        96
#       weighted avg 0.71      0.72      0.71        96

# %% [markdown]
# - Oversampling : DONE
# - Age Groups: No
# - Outliers: No
#
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.72      0.64        29
#            1       0.86      0.76      0.81        67
#
#       accuracy                         0.75        96
#       macro avg    0.72      0.74      0.72        96
#       weighted avg 0.77      0.75      0.76        96

# %% [markdown]
# - Oversampling : No
# - Age Groups: DONE
# - Outliers: DONE
#
#
#               precision    recall  f1-score   support
#
#            0       0.47      0.39      0.42        18
#            1       0.81      0.85      0.83        54
#
#       accuracy                         0.74        72
#       macro avg    0.64      0.62      0.63        72
#       weighted avg 0.72      0.74      0.73        72

# %% [markdown]
# - PCA: DONE - 4 components
# - Oversampling : No
# - Age Groups: No
# - Outliers: No
#
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.39      0.41        18
#            1       0.80      0.83      0.82        54
#
#       accuracy                         0.72        72
#       macro avg    0.62      0.61      0.61        72
#       weighted avg 0.71      0.72      0.72        72

# %% [markdown]
# - PCA: DONE - 2 components
# - Oversampling : No
# - Age Groups: No
# - Outliers: No
#
#
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.28      0.37        18
#            1       0.79      0.93      0.85        54
#
#       accuracy                         0.76        72
#       macro avg    0.67      0.60      0.61        72
#       weighted avg 0.73      0.76      0.73        72

# %% [markdown]
# - PCA: DONE - 6 components
# - Oversampling : No
# - Age Groups: No
# - Outliers: No
#
#
#
#
#               precision    recall  f1-score   support
#
#            0       0.47      0.44      0.46        18
#            1       0.82      0.83      0.83        54
#
#       accuracy                         0.74        72
#       macro avg    0.64      0.64      0.64        72
#       weighted avg 0.73      0.74      0.73        72

# %% [markdown]
# - PCA: DONE - 8 components
# - Oversampling : No
# - Age Groups: No
# - Outliers: No
#
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.44      0.47        18
#            1       0.82      0.85      0.84        54
#
#       accuracy                         0.75        72
#       macro avg    0.66      0.65      0.65        72
#       weighted avg 0.74      0.75      0.74        72

# %% [markdown]
# - PCA: DONE - 6 components
# - Oversampling : DONE
# - Age Groups: No
# - Outliers: No
#
#
#               precision    recall  f1-score   support
#
#            0       0.46      0.72      0.57        18
#            1       0.89      0.72      0.80        54
#
#       accuracy                         0.72        72
#       macro avg    0.68      0.72      0.68        72
#       weighted avg 0.78      0.72      0.74        72

# %% [markdown]
# - PCA: No
# - Oversampling : No
# - Age Groups: No
# - Outliers: No
# - STANDARD SCALER
#
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.44      0.48        18
#            1       0.82      0.87      0.85        54
#
#       accuracy                         0.76        72
#       macro avg    0.68      0.66      0.67        72
#       weighted avg 0.75      0.76      0.76        72

# %% [markdown]
# - PCA: Done - 6
# - Oversampling : No
# - Age Groups: Done
# - Outliers: Done
# - STANDARD SCALER
#
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.39      0.41        18
#            1       0.80      0.83      0.82        54
#
#       accuracy                         0.72        72
#       macro avg    0.62      0.61      0.61        72
#       weighted avg 0.71      0.72      0.72        72

# %% [markdown]
# - PCA: Done - 6
# - Oversampling : Done
# - Age Groups: Done
# - Outliers: Done
# - STANDARD SCALER
#
#
#               precision    recall  f1-score   support
#
#            0       0.46      0.72      0.57        18
#            1       0.89      0.72      0.80        54
#
#       accuracy                         0.72        72
#       macro avg    0.68      0.72      0.68        72
#       weighted avg 0.78      0.72      0.74        72

# %% [markdown]
# # Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %%
sns.set(rc={'figure.figsize':(8,6)})

# %%
liver_df = pd.read_csv('liverLabTrain.csv')

# %%
liver_df.head(10)
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
# 5   46    Male              1.8               0.7                   208
# 6   26  Female              0.9               0.2                   154
# 7   29  Female              0.9               0.3                   202
# 8   51    Male              2.9               1.3                   482
# 9   62    Male              6.8               3.0                   542
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# ...

# %% [markdown]
# # Data Visualization

# %%
sns.scatterplot(data = liver_df, x = 'Age', y= 'Alamine_Aminotransferase', hue= 'Liver_Disease')

# %%
sns.scatterplot(data = liver_df, x = 'Alamine_Aminotransferase', y= 'Albumin', hue= 'Liver_Disease')

# %%
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # Binarizing the gender column

# %%
for i,x in enumerate(liver_df['Gender']):
        
        if x.lower() == 'female':
            
            liver_df['Gender'].iloc[i] = 0
            
        else:
            
            liver_df['Gender'].iloc[i] = 1
# Out:
# d:\program files\python\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
liver_df.head(5)
# Out:
#    Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65      0              0.7               0.1                   187
# 1   62      1             10.9               5.5                   699
# 2   62      1              7.3               4.1                   490
# 3   58      1              1.0               0.4                   182
# 4   72      1              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Liver_Disease
# ...

# %%
liver_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 483 entries, 0 to 482
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         483 non-null    int64
#  1   Gender                      483 non-null    object
#  2   Total_Bilirubin             483 non-null    float64
#  3   Direct_Bilirubin            483 non-null    float64
#  4   Alkaline_Phosphotase        483 non-null    int64
#  5   Alamine_Aminotransferase    483 non-null    int64
#  6   Aspartate_Aminotransferase  483 non-null    int64
#  7   Total_Protiens              483 non-null    float64
#  8   Albumin                     483 non-null    float64
#  9   Albumin_and_Globulin_Ratio  480 non-null    float64
#  10  Liver_Disease               483 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 41.6+ KB

# %%
liver_df.describe(percentiles= [.25, .5, .80, .90])
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  483.000000       483.000000        483.000000            483.000000
# mean    44.722567         3.299172          1.466253            287.335404
# std     16.263700         6.358002          2.783368            232.322630
# min      4.000000         0.400000          0.100000             75.000000
# 25%     33.000000         0.800000          0.200000            174.500000
# 50%     45.000000         1.000000          0.300000            206.000000
# 80%     60.000000         3.260000          1.600000            338.000000
# 90%     66.000000         7.860000          4.000000            513.800000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                483.000000                  483.000000      483.000000
# ...

# %% [markdown]
# # Missing data

# %%
liver_df.dropna(inplace=True) #Dropping 3 rows where Albumin_and_Globulin_Ratio is na

# %% [markdown]
# # Outliers

# %%
cols = liver_df.columns

# %%
fig = plt.figure()
ax1 = fig.add_subplot(331)
ax2 = fig.add_subplot(332)
ax3 = fig.add_subplot(333)
ax4 = fig.add_subplot(334)
ax5 = fig.add_subplot(335)
ax6 = fig.add_subplot(336)
ax7 = fig.add_subplot(337)
ax8 = fig.add_subplot(338)


# basic plot
sns.boxplot(liver_df['Total_Bilirubin'], ax = ax1)

# notched plot
sns.boxplot(liver_df['Direct_Bilirubin'],ax = ax2)

# change outlier point symbols
sns.boxplot(liver_df['Alkaline_Phosphotase'], ax = ax3)

# don't show outlier points
sns.boxplot(liver_df['Alamine_Aminotransferase'],ax = ax4)

# horizontal boxes
sns.boxplot(liver_df['Aspartate_Aminotransferase'],ax = ax5)

# change whisker length
sns.boxplot(liver_df['Total_Protiens'],ax = ax6)

sns.boxplot(liver_df['Albumin'],ax = ax7)

sns.boxplot(liver_df['Albumin_and_Globulin_Ratio'],ax = ax8)

# %%
cols

# %%
def set_outlier(col,max_value, set_value, min_age = 0):
    
    #col: The column in data
    #max_value: the threshold of outliers
    #set_value: the highest possible value for instance
    
    for i,instance in enumerate(liver_df[col]):
        
        if liver_df['Age'].iloc[i] >= min_age:
            
            if instance >= max_value:
                liver_df[col].iloc[i] = set_value

# %%
#An elevation greater than 20 mg/dL suggests severe liver disease. 
#In patients with hepatitis-induced acute liver failure, 
#a serum total bilirubin level > 17.5 mg/dL (300 mmol/L) is a criterion for predicting death and the need for liver transplantation.

set_outlier('Total_Bilirubin', max_value= 20, set_value= 20)


#Typically, bilirubin levels fall somewhere between 0.3 and 1.2 milligrams per deciliter (mg/dL). 
#Anything above 1.2 mg/dL is usually considered high. 
#The condition of having high bilirubin levels is called hyperbilirubinemia

set_outlier('Direct_Bilirubin', max_value= 10, set_value= 10)


#The ALP level in healthy adults should be 20–140 units per liter (U/L). 
#Children tend to have significantly higher levels of ALP than adults because their bones are still growing. 
#A person recovering from a bone injury may also have a raised ALP level in the 3 months after the injury while their bone heals.


set_outlier('Alkaline_Phosphotase', max_value= 1000, set_value= 1000, min_age= 18)


#Typically the range for normal AST is reported between 10 to 40 units per liter and ALT between 7 to 56 units per liter. 
#Mild elevations are generally considered to be 2-3 times higher than the normal range. 
#In some conditions, these enzymes can be severely elevated, in the 1000s range

set_outlier('Alamine_Aminotransferase', max_value= 1000, set_value= 1000)


#Typically the range for normal AST is reported between 10 to 40 units per liter and ALT between 7 to 56 units per liter. 
#Mild elevations are generally considered to be 2-3 times higher than the normal range. 
#In some conditions, these enzymes can be severely elevated, in the 1000s range.

set_outlier('Aspartate_Aminotransferase', max_value= 1000, set_value= 1000)


#Total protein range. The normal range for total protein is between 6 and 8.3 grams per deciliter (g/dL). 
#This range may vary slightly among laboratories.

#Total Protein Plot seems OK



#Results are given in grams per deciliter (g/dL). A normal albumin range is 3.4 to 5.4 g/dL. 
#If you have a lower albumin level, you may have malnutrition. 
#It can also mean that you have liver disease or an inflammatory disease.


#Albumin plot seems OK


#A normal range of albumin is 39 to 51 grams per liter (g/L) of blood. 
#The normal range for globulins varies by specific type. A normal range for total globulins is 23 to 35 g/L. 
#If your protein level is low, you may have a liver or kidney problem.

# A/G Ratio seems OK

# %%
fig = plt.figure()
ax1 = fig.add_subplot(331)
ax2 = fig.add_subplot(332)
ax3 = fig.add_subplot(333)
ax4 = fig.add_subplot(334)
ax5 = fig.add_subplot(335)
ax6 = fig.add_subplot(336)
ax7 = fig.add_subplot(337)
ax8 = fig.add_subplot(338)


# basic plot
sns.boxplot(liver_df['Total_Bilirubin'], ax = ax1)

# notched plot
sns.boxplot(liver_df['Direct_Bilirubin'],ax = ax2)

# change outlier point symbols
sns.boxplot(liver_df['Alkaline_Phosphotase'], ax = ax3)

# don't show outlier points
sns.boxplot(liver_df['Alamine_Aminotransferase'],ax = ax4)

# horizontal boxes
sns.boxplot(liver_df['Aspartate_Aminotransferase'],ax = ax5)

# change whisker length
sns.boxplot(liver_df['Total_Protiens'],ax = ax6)

sns.boxplot(liver_df['Albumin'],ax = ax7)

sns.boxplot(liver_df['Albumin_and_Globulin_Ratio'],ax = ax8)

# %% [markdown]
# # Age groups

# %%
liver_df['child/teen'] = 0
liver_df['young'] = 0
liver_df['mid-age'] = 0
liver_df['old'] = 0

# %%
for i,instance in enumerate(liver_df['Age']):
    
    if instance < 18:
        liver_df['child/teen'].iloc[i] = 1
    elif 18 <= instance <= 40:
        liver_df['young'].iloc[i] = 1
    elif 40 < instance <= 60:
        liver_df['mid-age'].iloc[i] = 1
    elif 60 < instance:
        liver_df['old'].iloc[i] = 1

# %%
liver_df.drop(['child/teen'], axis = 1, inplace=True)

# %%
liver_df.drop(['Age'], axis = 1, inplace = True)

# %%
liver_df

# %% [markdown]
# # Visualizations

# %%
sns.countplot(liver_df['Liver_Disease'])

# %%
sns.countplot(data = liver_df, x = 'Gender', hue='Liver_Disease')

# %%
sns.pairplot(data = liver_df, hue = 'Liver_Disease')

# %%
sns.heatmap(liver_df.drop(['Liver_Disease'], axis=1).corr(), annot=True, vmin=-1,vmax=1)

# %% [markdown]
# # Preparing data for model

# %%
X = liver_df.drop(['Liver_Disease'], axis = 1)

# %%
y = liver_df['Liver_Disease'].values

# %%
X

# %%
y

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=3)

X_PCA = pca.fit_transform(X)

# %% [markdown]
# # Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_scaled = sc.fit_transform(X_PCA)

# %% [markdown]
# # Normalization

# %%
from sklearn import preprocessing

# %%
mm_scaler = preprocessing.MinMaxScaler()
df_mm = mm_scaler.fit_transform(X_PCA)

# %%
df_mm[0]

# %% [markdown]
# # Split train and test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.15, random_state=42)

# %% [markdown]
# # Oversampling

# %%
#https://beckernick.github.io/oversampling-modeling/

# %%
from imblearn.over_sampling import SMOTE
# Out:
# Using TensorFlow backend.

# %%
sm = SMOTE(random_state=42)
x_train_res, y_train_res = sm.fit_sample(X_train, y_train)

# %% [markdown]
# # Using GridSearchCV to find the best parameters for Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import plot_roc_curve

# %%
estimators = range(1,100,8)
criterion = ['gini', 'entropy']
min_samples_split = range(1,8)
max_features = ['auto', 'sqrt', 'log2']



# Create hyperparameter options
hyperparameters = dict(n_estimators=estimators,criterion = criterion,min_samples_split = min_samples_split, max_features=max_features)

# %%
rf = RandomForestClassifier(verbose=0, random_state=42)

# %%
clf = GridSearchCV(rf, hyperparameters,scoring='f1', cv=5, verbose=0)

# %%
best_model = clf.fit(x_train_res, y_train_res)
# Out:
# d:\program files\python\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   FitFailedWarning)
# d:\program files\python\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   FitFailedWarning)
# d:\program files\python\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ...

# %%
print('Best n_estimators:', best_model.best_estimator_.get_params()['n_estimators'])
print('Best criterion:', best_model.best_estimator_.get_params()['criterion'])
print('Best max_features:', best_model.best_estimator_.get_params()['max_features'])
print('Best min_samples_split:', best_model.best_estimator_.get_params()['min_samples_split'])
# Out:
# Best n_estimators: 65
# Best criterion: entropy
# Best max_features: auto
# Best min_samples_split: 3

# %% [markdown]
# # Training with the best parameters

# %%
tuned_rf = RandomForestClassifier(n_estimators=65,
                                  criterion='entropy',
                                  max_features='auto'
                                  ,min_samples_split=3)

# %%
tuned_rf.fit(x_train_res,y_train_res)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=3,
#                        min_weight_fraction_leaf=0.0, n_estimators=65,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_preds = tuned_rf.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.67      0.60        18
#            1       0.88      0.81      0.85        54
#
#     accuracy                           0.78        72
#    macro avg       0.71      0.74      0.72        72
# weighted avg       0.80      0.78      0.78        72

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_scores = cross_val_score(tuned_rf, X_scaled, y, cv=10)
#print each cv score (accuracy) and average them
print(cv_scores)
print('cv_scores mean:{}'.format(np.mean(cv_scores)))

# %%
rf_disp1 = plot_roc_curve(tuned_rf, X_test, y_test)

# %%
rf_disp1

# %%
from sklearn.metrics import confusion_matrix

# %%
sns.heatmap(confusion_matrix(y_test, y_preds), annot=True)
